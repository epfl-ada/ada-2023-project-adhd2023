# %% [markdown]
# # CREATING A DATASET FOR THE WORLD EVENTS USING OPENAI API:

# %%
from openai import OpenAI
import os
import time


#set up the API key
# hide the API key 
client = OpenAI(api_key="----")

# Define a function to fetch events for a given year
def fetch_events_for_year(year):
    prompt = f"I want you to respond in this way : year|event name|event description|country code|event category|year|event name|event description|country code|event category|year|event name|event description|country code|event category|year|event name|event description|country code|event category|year|event name|event description|country code|event category|year|event name|event description|country code|event category|year|event name|event description|country code|event category|year|event name|event description|country code|event category|: what is the top 8 most marking events of the year {year} ? (make 10 events for each year, I want the description to have about 70 words,the event location to be a country, the event category to be a litte general .don't make an introduction and don't forget the| between the events and at the end. for the event category i want it to be in this set:[Political Events,Military Conflicts,Social Movements,Economic Events,Science and health advancement,Cultural Events,Space Exploration,Sporting Events]. give the most significant events and don't focus on making the categroies number equal. "

    response = client.chat.completions.create(
    model="gpt-4",
    messages=[
    {"role": "user", "content": prompt} ]
    )
    content = response.choices[0].message.content
    return content

# Create a file to save the concatenated events
with open('historical_events_new.txt', 'a') as file:
    # Iterate over the years for which we want to fetch events
    for year in range(1820, 2014):
        # Fetch the events for the year
        events = fetch_events_for_year(year)
        # Save to the file
        file.write(events)
        
        # print the progress
        print(f"Events for {year} written to file.")
        
        #sleep for 0.05 seconds
        time.sleep(0.05)

# Print completion message
print("All events fetched and saved to file.")
# Out:
# Events for 1820 written to file.
# Events for 1821 written to file.
# Events for 1822 written to file.
# Events for 1823 written to file.
# Events for 1824 written to file.
# Events for 1825 written to file.
# Events for 1826 written to file.
# Events for 1827 written to file.
# Events for 1828 written to file.
# Events for 1829 written to file.
# Events for 1830 written to file.
# Events for 1831 written to file.
# Events for 1832 written to file.
# Events for 1833 written to file.
# Events for 1834 written to file.
# Events for 1835 written to file.
# Events for 1836 written to file.
# Events for 1837 written to file.
# Events for 1838 written to file.
# Events for 1839 written to file.
# Events for 1840 written to file.
# Events for 1841 written to file.
# Events for 1842 written to file.
# Events for 1843 written to file.
# Events for 1844 written to file.
# Events for 1845 written to file.
# Events for 1846 written to file.
# Events for 1847 written to file.
# Events for 1848 written to file.
# Events for 1849 written to file.
# Events for 1850 written to file.
# Events for 1851 written to file.
# Events for 1852 written to file.
# Events for 1853 written to file.
# Events for 1854 written to file.
# Events for 1855 written to file.
# Events for 1856 written to file.
# Events for 1857 written to file.
# Events for 1858 written to file.
# Events for 1859 written to file.
# Events for 1860 written to file.
# Events for 1861 written to file.
# Events for 1862 written to file.
# Events for 1863 written to file.
# Events for 1864 written to file.
# Events for 1865 written to file.
# Events for 1866 written to file.
# Events for 1867 written to file.
# Events for 1868 written to file.
# Events for 1869 written to file.
# Events for 1870 written to file.
# Events for 1871 written to file.
# Events for 1872 written to file.
# Events for 1873 written to file.
# Events for 1874 written to file.
# Events for 1875 written to file.
# Events for 1876 written to file.
# Events for 1877 written to file.
# Events for 1878 written to file.
# Events for 1879 written to file.
# Events for 1880 written to file.
# Events for 1881 written to file.
# Events for 1882 written to file.
# Events for 1883 written to file.
# Events for 1884 written to file.
# Events for 1885 written to file.
# Events for 1886 written to file.
# Events for 1887 written to file.
# Events for 1888 written to file.
# Events for 1889 written to file.
# Events for 1890 written to file.
# Events for 1891 written to file.
# Events for 1892 written to file.
# Events for 1893 written to file.
# Events for 1894 written to file.
# Events for 1895 written to file.
# Events for 1896 written to file.
# Events for 1897 written to file.
# Events for 1898 written to file.
# Events for 1899 written to file.
# Events for 1900 written to file.
# Events for 1901 written to file.
# Events for 1902 written to file.
# Events for 1903 written to file.
# Events for 1904 written to file.
# Events for 1905 written to file.
# Events for 1906 written to file.
# Events for 1907 written to file.
# Events for 1908 written to file.
# Events for 1909 written to file.
# Events for 1910 written to file.
# Events for 1911 written to file.
# Events for 1912 written to file.
# Events for 1913 written to file.
# Events for 1914 written to file.
# Events for 1915 written to file.
# Events for 1916 written to file.
# Events for 1917 written to file.
# Events for 1918 written to file.
# Events for 1919 written to file.
# Events for 1920 written to file.
# Events for 1921 written to file.
# Events for 1922 written to file.
# Events for 1923 written to file.
# Events for 1924 written to file.
# Events for 1925 written to file.
# Events for 1926 written to file.
# Events for 1927 written to file.
# Events for 1928 written to file.
# Events for 1929 written to file.
# Events for 1930 written to file.
# Events for 1931 written to file.
# Events for 1932 written to file.
# Events for 1933 written to file.
# Events for 1934 written to file.
# Events for 1935 written to file.
# Events for 1936 written to file.
# Events for 1937 written to file.
# Events for 1938 written to file.
# Events for 1939 written to file.
# Events for 1940 written to file.
# Events for 1941 written to file.
# Events for 1942 written to file.
# Events for 1943 written to file.
# Events for 1944 written to file.
# Events for 1945 written to file.
# Events for 1946 written to file.
# Events for 1947 written to file.
# Events for 1948 written to file.
# Events for 1949 written to file.
# Events for 1950 written to file.
# Events for 1951 written to file.
# Events for 1952 written to file.
# Events for 1953 written to file.
# Events for 1954 written to file.
# Events for 1955 written to file.
# Events for 1956 written to file.
# Events for 1957 written to file.
# Events for 1958 written to file.
# Events for 1959 written to file.
# Events for 1960 written to file.
# Events for 1961 written to file.
# Events for 1962 written to file.
# Events for 1963 written to file.
# Events for 1964 written to file.
# Events for 1965 written to file.
# Events for 1966 written to file.
# Events for 1967 written to file.
# Events for 1968 written to file.
# Events for 1969 written to file.
# Events for 1970 written to file.
# Events for 1971 written to file.
# Events for 1972 written to file.
# Events for 1973 written to file.
# Events for 1974 written to file.
# Events for 1975 written to file.
# Events for 1976 written to file.
# Events for 1977 written to file.
# Events for 1978 written to file.
# Events for 1979 written to file.
# Events for 1980 written to file.
# Events for 1981 written to file.
# Events for 1982 written to file.
# Events for 1983 written to file.
# Events for 1984 written to file.
# Events for 1985 written to file.
# Events for 1986 written to file.
# Events for 1987 written to file.
# Events for 1988 written to file.
# Events for 1989 written to file.
# Events for 1990 written to file.
# Events for 1991 written to file.
# Events for 1992 written to file.
# Events for 1993 written to file.
# Events for 1994 written to file.
# Events for 1995 written to file.
# Events for 1996 written to file.
# Events for 1997 written to file.
# Events for 1998 written to file.
# Events for 1999 written to file.
# Events for 2000 written to file.
# Events for 2001 written to file.
# Events for 2002 written to file.
# Events for 2003 written to file.
# Events for 2004 written to file.
# Events for 2005 written to file.
# Events for 2006 written to file.
# Events for 2007 written to file.
# Events for 2008 written to file.
# Events for 2009 written to file.
# Events for 2010 written to file.
# Events for 2011 written to file.
# Events for 2012 written to file.
# Events for 2013 written to file.
# All events fetched and saved to file.

# %%
import pandas as pd
def parse_events_to_dataframe(file_path):
    """
    Parses a text file with event data separated by vertical bars into a pandas DataFrame.

    Parameters:
    file_path (str): The path to the text file containing the event data.

    Returns:
    pd.DataFrame: A DataFrame with the columns ['Year', 'Event Name', 'Event Description', 'Event Location', 'Event Category'].
    """
    # Read the content of the file
    with open(file_path, 'r') as file:
        content = file.read()
    
    # Split the content by the delimiter "|"
    event_data = [e for e in content.split('|') if e]

    # The structure is expected to be a repeating sequence of 5 fields: year, name, description, location, category
    events = []
    for i in range(0, len(event_data), 5):
        year, name, description, location, category = event_data[i:i+5]
        events.append((year.strip(), name.strip(), description.strip(), location.strip(), category.strip()))

    # Create a DataFrame from the list of tuples
    df_columns = ['Year', 'Event Name', 'Event Description', 'Event Location', 'Event Category']
    events_df = pd.DataFrame(events, columns=df_columns)

    return events_df


file_path = 'historical_events_new.txt'  # Replace with the path to your file
events_dataframe = parse_events_to_dataframe(file_path)
print(events_dataframe.head())  # To display the first few rows of the DataFrame
#convert first column to int
events_dataframe['Year'] = events_dataframe['Year'].astype(int)

#write the dataframe to a csv file
events_dataframe.to_csv('events_new.csv', index=False)
# Out:
#    Year                  Event Name  \
# 0  1820         Missouri Compromise
# 1  1820         Antarctic Discovery
# 2  1820  The Cato Street Conspiracy
# 3  1820         Death of George III
# 4  1820    Establishment of Liberia
#
#                                    Event Description Event Location  \
# 0  The U.S. Congress passes the Missouri Compromi...            USA
# 1  The British explorer James Weddell discovers t...            GBR
# 2  An attempt to murder all the British cabinet m...            GBR
# 3  King George III of the United Kingdom passes a...            GBR
# 4  American Colonization Society purchases a smal...            LBR
#
#                    Event Category
# 0                Political Events
# 1  Science and health advancement
# 2                Political Events
# 3                Political Events
# 4                Social Movements
